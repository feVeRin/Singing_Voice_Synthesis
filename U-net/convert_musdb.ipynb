# %% [markdown]
# ## MUSDB 속성
#
# - __Track.name__ :  the track name, consisting of Track.artist and Track.title.
# - __Track.path__ : the absolute path of the mixture which might be handy to process with external applications.
# - __Track.audio__ : stereo mixture as an numpy array of shape (nb_samples, 2).
# - __Track.rate__ : the sample rate of the mixture.
# - __Track.sources__ : a dictionary of sources used for this track.
# - __Track.stems__ : an numpy tensor of all five stereo sources of shape (5, nb_samples, 2). The stems are always in the following order: ['mixture', 'drums', 'bass', 'other', 'vocals'],
# - __Track.targets__ : a dictionary of targets provided for this track.  ('mixture', 'drums', 'bass', 'other', 'vocals', 'accompaniment', 'linear_mixture')

# %%
import argparse
import os
import subprocess
import tempfile

import librosa
import numpy as np
import soundfile as sf


sr = 22050
origin_dataset_dir = '/userHome/userhome2/dahyun/voice/Singing_Voice_Synthesis/data/MUSDB18'
new_dataset_dir = '/userHome/userhome2/dahyun/voice/Singing_Voice_Synthesis/data/convertMUSDB'

if not os.path.isdir(new_dataset_dir):
    os.mkdir(new_dataset_dir)

os.mkdir(os.path.join(new_dataset_dir, 'train'))
os.mkdir(os.path.join(new_dataset_dir, 'test'))

# %%
with tempfile.TemporaryDirectory() as tmpdir:
    for subdir in ('train', 'test'):
        origin_dir = os.path.join(origin_dataset_dir, subdir)
        files = [f for f in os.listdir(origin_dir) if os.path.splitext(f)[1] == '.mp4']
        
        for file in files:
            path = os.path.join(origin_dir, file)
            name = os.path.splitext(file)[0]
            wav_data = []
                # Extract & save the sound of `ch` channel to a temp directory
                # and then concatenate all channels to a single .wav file
            for ch in range(5):
                temp_fn = f'{name}.{ch}.wav'
                out_path = os.path.join(tmpdir, temp_fn)
                subprocess.run(['ffmpeg', '-i', path,'-map', f'0:{ch}', out_path])
                sound, _ = librosa.load(out_path, sr=sr, mono=True)
                wav_data.append(sound)
            wav_data = np.stack(wav_data, axis=1)
            out_path = os.path.join(new_dataset_dir, subdir, f'{name}.wav')
            sf.write(out_path, wav_data, sr)
# Out:
# ffmpeg version 4.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/userHome/userhome2/dahyun/miniconda3/envs/svs --cc=/opt/conda/conda-bld/ffmpeg_1597178665428/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x556555c8cbc0] stream 0, timescale not set
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/userHome/userhome2/dahyun/voice/Singing_Voice_Synthesis/data/MUSDB18/train/Traffic Experiment - Once More (With Feeling).stem.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isom
#     creation_time   : 2017-12-16T17:30:27.000000Z
#   Duration: 00:07:15.06, start: 0.000000, bitrate: 1287 kb/s
#     Stream #0:0(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:2(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:3(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:4(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:5: Video: png, rgba(pc), 512x512 [SAR 20157:20157 DAR 1:1], 90k tbr, 90k tbn, 90k tbc (attached pic)
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/tmp/tmpaflzc4qi/Traffic Experiment - Once More (With Feeling).stem.0.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isom
#     ISFT            : Lavf58.45.100
#     Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc58.91.100 pcm_s16le
# size=   74948kB time=00:07:15.07 bitrate=1411.2kbits/s speed= 581x
# video:0kB audio:74948kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000102%
# ffmpeg version 4.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/userHome/userhome2/dahyun/miniconda3/envs/svs --cc=/opt/conda/conda-bld/ffmpeg_1597178665428/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x555a93a3dbc0] stream 0, timescale not set
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/userHome/userhome2/dahyun/voice/Singing_Voice_Synthesis/data/MUSDB18/train/Traffic Experiment - Once More (With Feeling).stem.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isom
#     creation_time   : 2017-12-16T17:30:27.000000Z
#   Duration: 00:07:15.06, start: 0.000000, bitrate: 1287 kb/s
#     Stream #0:0(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:2(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:3(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:4(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:5: Video: png, rgba(pc), 512x512 [SAR 20157:20157 DAR 1:1], 90k tbr, 90k tbn, 90k tbc (attached pic)
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/tmp/tmpaflzc4qi/Traffic Experiment - Once More (With Feeling).stem.1.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isom
#     ISFT            : Lavf58.45.100
#     Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc58.91.100 pcm_s16le
# size=   74948kB time=00:07:15.07 bitrate=1411.2kbits/s speed= 649x
# video:0kB audio:74948kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000102%
# ffmpeg version 4.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/userHome/userhome2/dahyun/miniconda3/envs/svs --cc=/opt/conda/conda-bld/ffmpeg_1597178665428/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x5587df7d9bc0] stream 0, timescale not set
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/userHome/userhome2/dahyun/voice/Singing_Voice_Synthesis/data/MUSDB18/train/Traffic Experiment - Once More (With Feeling).stem.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isom
#     creation_time   : 2017-12-16T17:30:27.000000Z
#   Duration: 00:07:15.06, start: 0.000000, bitrate: 1287 kb/s
#     Stream #0:0(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:2(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:3(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:4(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:5: Video: png, rgba(pc), 512x512 [SAR 20157:20157 DAR 1:1], 90k tbr, 90k tbn, 90k tbc (attached pic)
# Stream mapping:
#   Stream #0:2 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/tmp/tmpaflzc4qi/Traffic Experiment - Once More (With Feeling).stem.2.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isom
#     ISFT            : Lavf58.45.100
#     Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc58.91.100 pcm_s16le
# size=   74948kB time=00:07:15.07 bitrate=1411.2kbits/s speed= 897x
# video:0kB audio:74948kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.
start: 0.000000, bitrate: 1288 kb/s
#     Stream #0:0(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:2(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:3(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:4(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:5: Video: png, rgba(pc), 512x512 [SAR 20157:20157 DAR 1:1], 90k tbr, 90k tbn, 90k tbc (attached pic)
# Stream mapping:
#   Stream #0:3 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/tmp/tmpaflzc4qi/Clara Berry And Wooldog - Air Traffic.stem.3.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isom
#     ISFT            : Lavf58.45.100
#     Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc58.91.100 pcm_s16le
# size=   29848kB time=00:02:53.26 bitrate=1411.2kbits/s speed=1.08e+03x
# video:0kB audio:29848kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000255%
# ffmpeg version 4.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/userHome/userhome2/dahyun/miniconda3/envs/svs --cc=/opt/conda/conda-bld/ffmpeg_1597178665428/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x55c1b9fdcbc0] stream 0, timescale not set
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/userHome/userhome2/dahyun/voice/Singing_Voice_Synthesis/data/MUSDB18/train/Clara Berry And Wooldog - Air Traffic.stem.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isom
#     creation_time   : 2017-12-16T16:58:44.000000Z
#   Duration: 00:02:53.25, start: 0.000000, bitrate: 1288 kb/s
#     Stream #0:0(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:2(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:3(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:4(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:5: Video: png, rgba(pc), 512x512 [SAR 20157:20157 DAR 1:1], 90k tbr, 90k tbn, 90k tbc (attached pic)
# Stream mapping:
#   Stream #0:4 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/tmp/tmpaflzc4qi/Clara Berry And Wooldog - Air Traffic.stem.4.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isom
#     ISFT            : Lavf58.45.100
#     Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc58.91.100 pcm_s16le
# size=   29848kB time=00:02:53.26 bitrate=1411.2kbits/s speed=1.04e+03x
# video:0kB audio:29848kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000255%
# ffmpeg version 4.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/userHome/userhome2/dahyun/miniconda3/envs/svs --cc=/opt/conda/conda-bld/ffmpeg_1597178665428/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x55ea85270bc0] stream 0, timescale not set
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/userHome/userhome2/dahyun/voice/Singing_Voice_Synthesis/data/MUSDB18/train/Drumtracks - Ghost Bitch.stem.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isom
#     creation_time   : 2017-12-16T17:02:26.000000Z
#   Duration: 00:05:56.89, start: 0.000000, bitrate: 1287 kb/s
#     Stream #0:0(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:2(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:3(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:4(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:5: Video: png, rgba(pc), 512x512 [SAR 20157:20157 DAR 1:1], 90k tbr, 90k tbn, 90k tbc (attached pic)
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/tmp/tmpaflzc4qi/Drumtracks - Ghost Bitch.stem.0.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isom
#     ISFT            : Lavf58.45.100
#     Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc58.91.100 pcm_s16le
# size=   61484kB time=00:05:56.91 bitrate=1411.2kbits/s speed= 738x
# video:0kB audio:61484kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000124%
# ffmpeg version 4.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/userHome/userhome2/dahyun/miniconda3/envs/svs --cc=/opt/conda/conda-bld/ffmpeg_1597178665428/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x555944a07bc0] stream 0, timescale not set
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/userHome/userhome2/dahyun/voice/Singing_Voice_Synthesis/data/MUSDB18/train/Drumtracks - Ghost Bitch.stem.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isom
#     creation_time   : 2017-12-16T17:02:26.000000Z
#   Duration: 00:05:56.89, start: 0.000000, bitrate: 1287 kb/s
#     Stream #0:0(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:2(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:3(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:4(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:5: Video: png, rgba(pc), 512x512 [SAR 20157:20157 DAR 1:1], 90k tbr, 90k tbn, 90k tbc (attached pic)
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/tmp/tmpaflzc4qi/Drumtracks - Ghost Bitch.stem.1.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isom
#     ISFT            : Lavf58.45.100
#     Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc58.91.100 pcm_s16le
# ...
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x55744fa2bbc0] stream 0, timescale not set
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/userHome/userhome2/dahyun/voice/Singing_Voice_Synthesis/data/MUSDB18/test/Carlos Gonzalez - A Place For Us.stem.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isom
#     creation_time   : 2017-12-16T16:29:34.000000Z
#   Duration: 00:04:10.02, start: 0.000000, bitrate: 1288 kb/s
#     Stream #0:0(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:2(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:3(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:4(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:5: Video: png, rgba(pc), 512x512 [SAR 20157:20157 DAR 1:1], 90k tbr, 90k tbn, 90k tbc (attached pic)
# Stream mapping:
#   Stream #0:4 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/tmp/tmpaflzc4qi/Carlos Gonzalez - A Place For Us.stem.4.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isom
#     ISFT            : Lavf58.45.100
#     Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc58.91.100 pcm_s16le
# size=   43072kB time=00:04:10.03 bitrate=1411.2kbits/s speed=1.05e+03x
# video:0kB audio:43072kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000177%
# ffmpeg version 4.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/userHome/userhome2/dahyun/miniconda3/envs/svs --cc=/opt/conda/conda-bld/ffmpeg_1597178665428/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x55b9ecfc4bc0] stream 0, timescale not set
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/userHome/userhome2/dahyun/voice/Singing_Voice_Synthesis/data/MUSDB18/test/Zeno - Signs.stem.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isom
#     creation_time   : 2017-12-16T16:49:09.000000Z
#   Duration: 00:03:54.18, start: 0.000000, bitrate: 1288 kb/s
#     Stream #0:0(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:2(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:3(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:4(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:5: Video: png, rgba(pc), 512x512 [SAR 20157:20157 DAR 1:1], 90k tbr, 90k tbn, 90k tbc (attached pic)
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/tmp/tmpaflzc4qi/Zeno - Signs.stem.0.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isom
#     ISFT            : Lavf58.45.100
#     Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc58.91.100 pcm_s16le
# size=   40344kB time=00:03:54.19 bitrate=1411.2kbits/s speed= 575x
# video:0kB audio:40344kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000189%
# ffmpeg version 4.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/userHome/userhome2/dahyun/miniconda3/envs/svs --cc=/opt/conda/conda-bld/ffmpeg_1597178665428/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x55f1f10f9bc0] stream 0, timescale not set
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/userHome/userhome2/dahyun/voice/Singing_Voice_Synthesis/data/MUSDB18/test/Zeno - Signs.stem.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isom
#     creation_time   : 2017-12-16T16:49:09.000000Z
#   Duration: 00:03:54.18, start: 0.000000, bitrate: 1288 kb/s
#     Stream #0:0(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:2(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:3(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:4(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:5: Video: png, rgba(pc), 512x512 [SAR 20157:20157 DAR 1:1], 90k tbr, 90k tbn, 90k tbc (attached pic)
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/tmp/tmpaflzc4qi/Zeno - Signs.stem.1.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isom
#     ISFT            : Lavf58.45.100
#     Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc58.91.100 pcm_s16le
# size=   40344kB time=00:03:54.19 bitrate=1411.2kbits/s speed= 713x
# video:0kB audio:40344kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000189%
# ffmpeg version 4.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/userHome/userhome2/dahyun/miniconda3/envs/svs --cc=/opt/conda/conda-bld/ffmpeg_1597178665428/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x55f339dd1bc0] stream 0, timescale not set
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/userHome/userhome2/dahyun/voice/Singing_Voice_Synthesis/data/MUSDB18/test/Zeno - Signs.stem.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isom
#     creation_time   : 2017-12-16T16:49:09.000000Z
#   Duration: 00:03:54.18, start: 0.000000, bitrate: 1288 kb/s
#     Stream #0:0(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:2(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:3(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:4(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:5: Video: png, rgba(pc), 512x512 [SAR 20157:20157 DAR 1:1], 90k tbr, 90k tbn, 90k tbc (attached pic)
# Stream mapping:
#   Stream #0:2 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/tmp/tmpaflzc4qi/Zeno - Signs.stem.2.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isom
#     ISFT            : Lavf58.45.100
#     Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc58.91.100 pcm_s16le
# size=   40344kB time=00:03:54.19 bitrate=1411.2kbits/s speed= 925x
# video:0kB audio:40344kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000189%
# ffmpeg version 4.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/userHome/userhome2/dahyun/miniconda3/envs/svs --cc=/opt/conda/conda-bld/ffmpeg_1597178665428/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x55d409e89bc0] stream 0, timescale not set
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/userHome/userhome2/dahyun/voice/Singing_Voice_Synthesis/data/MUSDB18/test/Zeno - Signs.stem.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isom
#     creation_time   : 2017-12-16T16:49:09.000000Z
#   Duration: 00:03:54.18, start: 0.000000, bitrate: 1288 kb/s
#     Stream #0:0(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:2(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:3(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:4(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:5: Video: png, rgba(pc), 512x512 [SAR 20157:20157 DAR 1:1], 90k tbr, 90k tbn, 90k tbc (attached pic)
# Stream mapping:
#   Stream #0:3 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/tmp/tmpaflzc4qi/Zeno - Signs.stem.3.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isom
#     ISFT            : Lavf58.45.100
#     Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc58.91.100 pcm_s16le
# size=   40344kB time=00:03:54.19 bitrate=1411.2kbits/s speed=1.02e+03x
# video:0kB audio:40344kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000189%
# ffmpeg version 4.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/userHome/userhome2/dahyun/miniconda3/envs/svs --cc=/opt/conda/conda-bld/ffmpeg_1597178665428/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x556c7c16bbc0] stream 0, timescale not set
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/userHome/userhome2/dahyun/voice/Singing_Voice_Synthesis/data/MUSDB18/test/Zeno - Signs.stem.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isom
#     creation_time   : 2017-12-16T16:49:09.000000Z
#   Duration: 00:03:54.18, start: 0.000000, bitrate: 1288 kb/s
#     Stream #0:0(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:2(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:3(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:4(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 256 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:5: Video: png, rgba(pc), 512x512 [SAR 20157:20157 DAR 1:1], 90k tbr, 90k tbn, 90k tbc (attached pic)
# Stream mapping:
#   Stream #0:4 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/tmp/tmpaflzc4qi/Zeno - Signs.stem.4.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isom
#     ISFT            : Lavf58.45.100
#     Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc58.91.100 pcm_s16le
# size=   40344kB time=00:03:54.19 bitrate=1411.2kbits/s speed=1.06e+03x
# video:0kB audio:40344kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000189%
